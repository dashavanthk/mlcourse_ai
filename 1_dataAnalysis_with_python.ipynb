# %%
import numpy as np
import pandas as pd
# to ignore warnings!
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the file
df = pd.read_csv('./data/telecom_churn.csv')
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [raw]
# Showing only limited number of column for large dataset
# pd.set_option('display.max_columns',100)

# %% [raw]
# To display normal pandas way of displaying the data

# %%
print(df.head())
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
#For dimensionality

print(df.shape)
# Out:
# (3333, 20)

# %%
# To display all the columns 
print(df.columns)
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# To get all columns info
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
# State                     3333 non-null object
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null object
# Voice mail plan           3333 non-null object
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total day charge          3333 non-null float64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total eve charge          3333 non-null float64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total night charge        3333 non-null float64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Total intl charge         3333 non-null float64
# ...

# %%
# To change the data type of the particular column
df['Churn'] = df['Churn'].astype('int64')

# Check the column data type
c = df['Churn'].dtypes

print('df['+'Churn'+'] data type :', c)
print('------------------------------------')
print(df.info())
# Out:
# df[Churn] data type : int64
# ------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
# State                     3333 non-null object
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null object
# Voice mail plan           3333 non-null object
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total day charge          3333 non-null float64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total eve charge          3333 non-null float64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total night charge        3333 non-null float64
# Total intl minutes        3333 non-null float64
# ...

# %%
# To display column -[Series]
ChurnSeries = df.Churn
print(ChurnSeries.head()) # head() only to reduce to the number of records -[Look Pretty]
print('dataType:',ChurnSeries.dtypes)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Churn, dtype: int64
# dataType: int64

# %%
# details of the dataFrame

df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
# To filter out the columns - Use "Include" inside describe() - - the dataType
df.describe(include=['float64'])
# Out:
#        Total day minutes  Total day charge  Total eve minutes  \
# count        3333.000000       3333.000000        3333.000000
# mean          179.775098         30.562307         200.980348
# std            54.467389          9.259435          50.713844
# min             0.000000          0.000000           0.000000
# 25%           143.700000         24.430000         166.600000
# 50%           179.400000         30.500000         201.400000
# 75%           216.400000         36.790000         235.300000
# max           350.800000         59.640000         363.700000
#
#        Total eve charge  Total night minutes  Total night charge  \
# count       3333.000000          3333.000000         3333.000000
# mean          17.083540           200.872037            9.039325
# std            4.310668            50.573847            2.275873
# min            0.000000            23.200000            1.040000
# 25%           14.160000           167.000000            7.520000
# ...

# %%
df.describe(include=['object','bool'])
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %% [raw]
# For categorical (type object) and boolean (type bool) features we can use the value_counts method.

# %%
df['Area code'].value_counts()
# Out:
# 415    1655
# 510     840
# 408     838
# Name: Area code, dtype: int64

# %%
# To Calculate the Normalized values
df['Area code'].value_counts(normalize = True)
# Out:
# 415    0.496550
# 510    0.252025
# 408    0.251425
# Name: Area code, dtype: float64

# %% [raw]
# Sorting through column values

# %%
#Sorting single column
df.sort_values(by=['Area code'], ascending = True).head()
        # -- Remove head() if not required
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 2536    CT             119        408                 No              No
# 887     IA             128        408                 No              No
# 2486    MS              76        408                 No              No
# 2482    MT             157        408                 No              No
# 2476    WV              84        408                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 2536                      0              294.2              100
# 887                       0              158.8               75
# 2486                      0              173.2               93
# 2482                      0              240.2               67
# 2476                      0              146.8              133
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
# Multiple columns
df.sort_values(by=['Area code','Total day calls'], ascending = [True, False]).head()
        # -- Remove head() if not needed.
# df.sort_values(by=['Area code','Total day calls','Total day charge'], ascending = [True, False, True]).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 315     MA              39        408                 No              No
# 1869    MS             101        408                 No              No
# 2010    NC              89        408                 No              No
# 870     OH             123        408                 No              No
# 989     NV             178        408                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 315                       0               60.4              158
# 1869                      0              239.0              156
# 2010                      0              105.9              151
# 870                       0              105.0              150
# 989                       0              275.4              150
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df['Total day charge'].mean()
# Out:
# 30.562307230723093

# %%
df['Churn'].mean()
# Out:
# 0.14491449144914492

# %% [raw]
# Boolean indexing with one column is also very convenient. The syntax is df[P(df['Name'])], where P is some logical condition that is checked for each element of the Name column. The result of such indexing is the DataFrame consisting only of rows that satisfy the P condition on the Name column.

# %%
df[df['Voice mail plan']=='Yes'].mean()
# Out:
# Account length            101.252711
# Area code                 437.131236
# Number vmail messages      29.277657
# Total day minutes         179.626790
# Total day calls           100.075922
# Total day charge           30.537072
# Total eve minutes         202.746963
# Total eve calls            99.906725
# Total eve charge           17.233796
# Total night minutes       201.369089
# Total night calls         100.599783
# Total night charge          9.061638
# Total intl minutes         10.231345
# Total intl calls            4.509761
# Total intl charge           2.763026
# Customer service calls      1.524946
# Churn                       0.086768
# dtype: float64

# %%
df[df['Churn']==1].mean()
# Out:
# Account length            102.664596
# Area code                 437.817805
# Number vmail messages       5.115942
# Total day minutes         206.914079
# Total day calls           101.335404
# Total day charge           35.175921
# Total eve minutes         212.410145
# Total eve calls           100.561077
# Total eve charge           18.054969
# Total night minutes       205.231677
# Total night calls         100.399586
# Total night charge          9.235528
# Total intl minutes         10.700000
# Total intl calls            4.163561
# Total intl charge           2.889545
# Customer service calls      2.229814
# Churn                       1.000000
# dtype: float64

# %%
df[df['Voice mail plan']=='Yes']['Total night calls'].mean()
# Out:
# 100.59978308026031

# %%
df[(df['Churn']==0) & (df['International plan']=='No')]['Total intl minutes'].max()
# Out:
# 18.899999999999999

# %% [raw]
# # loc   method used for indexing by name
# # iloc  mothod used for indexing by number

# %%
df.loc[0:5,'Area code':'Total eve calls']
# Out:
#    Area code International plan Voice mail plan  Number vmail messages  \
# 0        415                 No             Yes                     25
# 1        415                 No             Yes                     26
# 2        415                 No              No                      0
# 3        408                Yes              No                      0
# 4        415                Yes              No                      0
# 5        510                Yes              No                      0
#
#    Total day minutes  Total day calls  Total day charge  Total eve minutes  \
# 0              265.1              110             45.07              197.4
# 1              161.6              123             27.47              195.5
# 2              243.4              114             41.38              121.2
# 3              299.4               71             50.90               61.9
# 4              166.7              113             28.34              148.3
# ...

# %%
df.iloc[0:5,1:5]
# Out:
#    Account length  Area code International plan Voice mail plan
# 0             128        415                 No             Yes
# 1             107        415                 No             Yes
# 2             137        415                 No              No
# 3              84        408                Yes              No
# 4              75        415                Yes              No

# %% [markdown]
# Applying Functions to cells, columns and Rows
#         apply()

# %%
df.apply(np.max)
# Out:
# State                        WY
# Account length              243
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        51
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             170
# Total eve charge          30.91
# Total night minutes         395
# Total night calls           175
# Total night charge        17.77
# Total intl minutes           20
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                         1
# dtype: object

# %%
df[df['Account length']==243]
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 817    UT             243        510                 No              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 817                      0               95.5               92
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 817             16.24              163.7               63             13.91
#
#      Total night minutes  Total night calls  Total night charge  \
# 817                264.2                118               11.89
#
#      Total intl minutes  Total intl calls  Total intl charge  \
# 817                 6.6                 6               1.78
#
#      Customer service calls  Churn
# 817                       2      0

# %% [markdown]
# The apply method can also be used to apply a function to each row. To do this, specify axis=1. Lambda functions are very convenient in such scenarios. For example, if we need to select all states starting with W, we can do it like this

# %%
df[df['Area code'].apply(lambda state: state%5==0)].head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 4                      0              166.7              113
# 5                      0              223.4               98
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [raw]
# To replace Values in Column with other values ----- functions .map(Object)

# %%
d={'Yes': True, 'No': False}

df['Voice mail plan'] = df['Voice mail plan'].map(d)
df.head()
# Out:
#   State  Account length  Area code International plan  Voice mail plan  \
# 0    KS             128        415                 No             True
# 1    OH             107        415                 No             True
# 2    NJ             137        415                 No            False
# 3    OH              84        408                Yes            False
# 4    OK              75        415                Yes            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df=df.replace({'International plan': d})
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [raw]
# df.groupby(by=grouping_columns)[columns_to_show].function()
#
# 1.First, the groupby method divides the grouping_columns by their values. They become a new index in the resulting dataframe.
# 2.Then, columns of interest are selected (columns_to_show). If columns_to_show is not included, all non groupby clauses will be   included.
# 3.Finally, one or several functions are applied to the obtained groups per selected columns.

# %%
col_to_show = ['Account length', 'Area code', 'Number vmail messages']
df.groupby(['Churn'])[col_to_show].describe(percentiles=[])
# Out:
#       Account length                                          Area code  \
#                count        mean       std  min    50%    max     count
# Churn
# False         2850.0  100.793684  39.88235  1.0  100.0  243.0    2850.0
# True           483.0  102.664596  39.46782  1.0  103.0  225.0     483.0
#
#                                                   Number vmail messages  \
#              mean        std    min    50%    max                 count
# Churn
# False  437.074737  42.306156  408.0  415.0  510.0                2850.0
# True   437.817805  42.792270  408.0  415.0  510.0                 483.0
#
#
#            mean        std  min  50%   max
# Churn
# False  8.604561  13.913125  0.0  0.0  51.0
# True   5.115942  11.860138  0.0  0.0  48.0

# %%
# slightly differnt usability

df.groupby(['Churn'])[col_to_show].agg([np.mean, np.std,np.max,np.min])
# Out:
#       Account length                       Area code                       \
#                 mean       std amax amin        mean        std amax amin
# Churn
# False     100.793684  39.88235  243    1  437.074737  42.306156  510  408
# True      102.664596  39.46782  225    1  437.817805  42.792270  510  408
#
#       Number vmail messages
#                        mean        std amax amin
# Churn
# False              8.604561  13.913125   51    0
# True               5.115942  11.860138   48    0

# %% [raw]
# Summary tables
# Suppose we want to see how the observations in our sample are distributed in the context of two variables - Churn and International plan. To do so, we can build a contingency table using the crosstab method:

# %%
pd.crosstab(df['Churn'],df['International plan'])
# Out:
# International plan  False  True
# Churn
# False                2664    186
# True                  346    137

# %%
pd.crosstab(df['Churn'], df['Voice mail plan'], normalize=True)
# Out:
# Voice mail plan     False     True
# Churn
# False            0.602460  0.252625
# True             0.120912  0.024002

# %% [raw]
# Pivot Table
#
# values – a list of variables to calculate statistics for,
# index – a list of variables to group data by,
# aggfunc – what statistics we need to calculate for groups, ex. sum, mean, maximum, minimum or something else.

# %%
df.pivot_table(['Total day calls','Total eve calls','Total night calls'],['Area code'], aggfunc = 'count')
# Out:
#            Total day calls  Total eve calls  Total night calls
# Area code
# 408                    838              838                838
# 415                   1655             1655               1655
# 510                    840              840                840

# %% [markdown]
# ### DataFrame transformations
#
# Like many other things in Pandas, adding columns to a DataFrame is doable in many ways.
#
# For example, if we want to calculate the total number of calls for all users, let’s create the total_calls Series and paste it into the DataFrame:

# %%
total_calls = df['Total day calls']+df['Total eve calls']+ df['Total night calls']+ df['Total intl calls']

# %%
df['Total calls'] = df['Total day calls']+df['Total eve calls']+ df['Total night calls']+ df['Total intl calls']

# %%
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes     ...       Total eve charge  \
# 0             45.07              197.4     ...                  16.78
# ...

# %%
total_charges = df['Total day charge']+df['Total eve charge']+ df['Total night charge']

df.insert(loc=len(df.columns), column='Total Charge', value = total_charges)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-488ad0278c47> in <module>()
#       1 total_charges = df['Total day charge']+df['Total eve charge']+ df['Total night charge']
#       2
# ----> 3 df.insert(loc=len(df.columns), column='Total Charge', value = total_charges)
#
# C:\Users\dashw\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    2421         value = self._sanitize_column(column, value, broadcast=False)
#    2422         self._data.insert(loc, column, value,
# -> 2423                           allow_duplicates=allow_duplicates)
#    2424
#    2425     def assign(self, **kwargs):
#
# C:\Users\dashw\Anaconda3\lib\site-packages\pandas\core\internals.py in insert(self, loc, item, value, allow_duplicates)
#    3808         if not allow_duplicates and item in self.items:
# ...

# %%
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes      ...       Total night minutes  \
# 0             45.07              197.4      ...                     244.7
# ...

# %% [raw]
# To delete columns or rows, use the drop method, passing the required indexes and the axis parameter (1 if you delete columns, and nothing or 0 if you delete rows). The inplace argument tells whether to change the original DataFrame. With inplace=False, the drop method doesn't change the existing DataFrame and returns a new one with dropped rows or columns. With inplace=True, it alters the DataFrame.

# %%
# To drop the columns

Tempdf = df.drop(['Total calls','Total Charge'],axis=1,inplace=False)
Tempdf.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# ### First attempt at predicting telecom churn

# %% [markdown]
# Let's see how churn rate is related to the International plan feature. We’ll do this using a crosstab contingency table and also through visual analysis with Seaborn (however, visual analysis will be covered more thoroughly in the next article).

# %%
pd.crosstab(df['Churn'],df['International plan'], margins=True)
# Out:
# International plan  False  True   All
# Churn
# False                2664   186  2850
# True                  346   137   483
# All                  3010   323  3333

# %%
# some imports to set up plotting 
# %matplotlib inline
import matplotlib.pyplot as plt
# pip install seaborn 
import seaborn as sns

# %%
sns.countplot(x='International plan',hue='Voice mail plan', data= df)
